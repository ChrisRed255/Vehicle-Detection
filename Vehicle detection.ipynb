# %% [markdown]
# # **Mounting Drive to Colab Workspace**

# %% [markdown]
# **Mount drive on colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # Download file from colab to local disk

# %%
from google.colab import files

files.download('example.txt')

# %% [markdown]
# # Preparing dataset

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle

from google.colab import files
files.upload()

# %%
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# **Kaggle datasets**

# %%
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets list

# %% [markdown]
# **Download Kaggle Cars dataset**

# %%
# !kaggle datasets download -d jessicali9530/stanford-cars-dataset

# %% [markdown]
# **Copying car dataset to drive**

# %%
# !cp /content/stanford-cars-dataset.zip /content/gdrive/'My Drive'/Colab/

# %% [markdown]
# **Download the landscape dataset (small dataset)**

# %%
# !wget https://github.com/ml5js/ml5-data-and-models/raw/master/datasets/images/landscapes/landscapes_small.zip

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # **Use a ready dataset and test dataset**

# %% [markdown]
# **Create a workspace folder and copy the dataset to it**

# %%
# !mkdir Workspace
# !cp /content/gdrive/'My Drive'/Colab/training.zip /content/Workspace

# %%
cd Workspace
# Out:
# /content/Workspace

# %% [markdown]
# **Copy pictures for test**

# %%
# !mkdir test
# !cp /content/gdrive/'My Drive'/Colab/pic1.jpg /content/gdrive/'My Drive'/Colab/pic2.jpeg /content/Workspace/test
# !cp /content/gdrive/'My Drive'/Colab/vehicle.jpg /content/gdrive/'My Drive'/Colab/vehicle2.jpg /content/Workspace/test
# !cp /content/gdrive/'My Drive'/share2.jpg /content/Workspace/test

# %%
# !cp /content/Workspace/augmentated_images.zip /content/gdrive/'My Drive'/Colab

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # **Preparing workspace for ready dataset**

# %% [markdown]
# **Access "Workspace" folder**

# %%
cd Workspace
# Out:
# /content/Workspace

# %% [markdown]
# **Unzip training zip file**

# %%
# !unzip training.zip
# Out:
# Archive:  training.zip
#    creating: Landscape/
#   inflating: Landscape/a0004.jpg
#   inflating: Landscape/a0010.jpg
#   inflating: Landscape/a111017.jpg
#   inflating: Landscape/a129035.jpg
#   inflating: Landscape/a129048.jpg
#   inflating: Landscape/a129053.jpg
#   inflating: Landscape/a140032.jpg
#   inflating: Landscape/a205062.jpg
#   inflating: Landscape/a212017.jpg
#   inflating: Landscape/a212018.jpg
#   inflating: Landscape/a212024.jpg
#   inflating: Landscape/a212025.jpg
#   inflating: Landscape/a212026.jpg
#   inflating: Landscape/a212033.jpg
#   inflating: Landscape/a212044.jpg
#   inflating: Landscape/a212052.jpg
#   inflating: Landscape/a212055.jpg
#   inflating: Landscape/a223039.jpg
#   inflating: Landscape/a223049.jpg
#   inflating: Landscape/a232022.jpg
#   inflating: Landscape/a244009.jpg
#   inflating: Landscape/a244030.jpg
#   inflating: Landscape/a244040.jpg
#   inflating: Landscape/a244043.jpg
#   inflating: Landscape/a244046.jpg
# ...

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # **Preparing workspace**

# %% [markdown]
# **Creating the file "Workspace" and move the zip file to that file**

# %%
# !mkdir Workspace
# !mv stanford-cars-dataset.zip Workspace

# %% [markdown]
# **Access to the "Workspace" file**

# %%
cd Workspace

# %% [markdown]
# **Unzip the dataset file**

# %%
# !unzip stanford-cars-dataset.zip

# %% [markdown]
# **Create "Car" file that holds the training car images**

# %%
# !mkdir Car
# !mv cars_train.zip Car
# Out:
# mkdir: cannot create directory ‘Car’: File exists
# mv: cannot stat 'cars_train.zip': No such file or directory

# %% [markdown]
# **Access to "Car" file**

# %%
cd Car

# %% [markdown]
# **Unzip the training data**

# %%
# !unzip cars_train.zip

# %% [markdown]
# **Cleaning the training data folder**

# %%
rm -r __MACOSX/

# %%
cd cars_train/

# %% [markdown]
# **Moving the training data to "Car" folder**

# %%
# !mv *.jpg /content/Workspace/Car

# %% [markdown]
# **Remove the useless files **

# %%
rm -r cars_train.zip cars_train/

# %% [markdown]
# **Creating "Landscape" file and move landscape dataset to it**

# %%
# !mkdir Landscape
# !mv landscapes_small.zip Landscape

# %% [markdown]
# **Access to "Landscape" folder**

# %%
cd Landscape/

# %% [markdown]
# **Unzip the landscape dataset**

# %%
# !unzip landscapes_small.zip

# %% [markdown]
# **Remove useless files**

# %%
rm -r __MACOSX/ landscapes_small.zip
rm -r city field forest lake mountain ocean road

# %% [markdown]
# **Create "AllPic" file and move all landscape pics to it**

# %%
# !mkdir AllPic
# !mv city/*.jpg forest/*.jpg lake/*.jpg ocean/*.jpg road/*.jpg field/*.jpg mountain/*.jpg AllPic

# %% [markdown]
# **Move from "AllPic" file to "Landscape" file**

# %%
# !mv AllPic/*.jpg /content/Workspace/Landscape

# %% [markdown]
# **Return to main folder**

# %%
cd /content

# %% [markdown]
# **Remove uiseless files**

# %%
rm -r cars_annos.mat stanford-cars-dataset.zip

# %% [markdown]
# **Create "CarTest" folder and move the test file to it **

# %%
# !mkdir CarTest
# !mv cars_test.zip CarTest
# Out:
# mv: cannot stat 'cars_test.zip': No such file or directory

# %% [markdown]
# **Unzip the test file**

# %%
# !unzip cars_test.zip

# %% [markdown]
# **Copy from drive car and landscape pics to test**

# %%
# !cp /content/gdrive/'My Drive'/Colab/pic1.jpg /content/gdrive/'My Drive'/Colab/pic2.jpeg /content/Workspace
# !cp /content/gdrive/'My Drive'/Colab/vehicle.jpg /content/gdrive/'My Drive'/Colab/vehicle2.jpg /content/Workspace
# !cp /content/gdrive/'My Drive'/share2.jpg /content/Workspace

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # Importing ready Workspace

# %% [markdown]
# **Copy workspace from drive**

# %%
# !cp /content/gdrive/'My Drive'/Colab/Workspace.zip /content/

# %% [markdown]
# **Unzip workspace**

# %%
# !unzip Workspace.zip

# %% [markdown]
# **Delete images folder**

# %%
rm -r Workspace/images

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # Using the VGG16 model ready on my drive

# %% [markdown]
# **Copy the VGG16 model from drive to workspace**

# %%
# !cp /content/gdrive/'My Drive'/Colab/vgg16_model.h5 /content/

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # OpenCV

# %%
from google.colab.patches import cv2_imshow

import cv2
import os

img = cv2.imread(os.path.join(train_path,"Car/00001.jpg"), cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # Programming part

# %% [markdown]
# **Access workspace**

# %%
cd Workspace
# Out:
# /content/Workspace

# %% [markdown]
# **Import packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import keras
import pickle
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Prepare data for model**

# %%
DATADIR = os.path.join(os.getcwd(),os.path.join("Workspace","train"))
CATEGORY = ['Car','Landscape']
IMG_SIZE = 400
training_data =[]

def create_training_data():
  print("En cours de traitement ...\n\n")
  for category in CATEGORY:
    path = os.path.join(DATADIR,category)
    class_num = CATEGORY.index(category)
    for img in os.listdir(path):
      try:
        img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_COLOR)
        new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
        training_data.append([new_array,class_num])
      except Exception as e:
        print("because of the category :"+category+", file : "+img+"\n"+str(e))
  print("Fin du traitement avec succès !\n\n")

create_training_data()
# Out:
# En cours de traitement ...
#
#
# Fin du traitement avec succès !

# %% [markdown]
# **Shuffle data**

# %%
for i in range(0,6):
  random.shuffle(training_data)

# %% [markdown]
# **Create matrix X that holds features and matrix Y that holds labels**

# %%
X = []
y = []

for features,label in training_data:
  X.append(features)
  y.append(label)

# %% [markdown]
# **Reshape the features matrix**

# %%
X.shape
# Out:
# (4718, 400, 400, 3)

# %%
X = np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,3)

# %% [markdown]
# **Save X and Y into pickle file to use it after**

# %%
pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %% [markdown]
# **Load pickle data X and Y**

# %%
X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

# %% [markdown]
# **Normalize data**

# %%
#X = keras.utils.normalize(X, axis=-1, order=2)
X = X/255.0

# %%
model = tf.keras.models.load_model()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# **Create the model 1**

# %%
model = Sequential()
try:
  model.add(Conv2D(32,(3,3),input_shape = (500,500,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(5,5)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Flatten())
  model.add(Dense(64))
  model.add(Dropout(0.3))
  
  model.add(Dense(1))
  model.add(Activation('sigmoid'))

except Exception as e:
  print("Error :",str(e))

# %%
#model.summary()
with open('modelInitial.txt','w') as fh:
    # Pass the file handle in as a lambda function to make it callable
    model.summary(print_fn=lambda x: fh.write(x + '\n'))

# %% [markdown]
# **Create model 2**

# %%
model = Sequential()
try:
  model.add(Conv2D(32,(3,3),input_shape = X.shape[1:]))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(1,1)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(1,1)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(64,(3,3)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))
  
  model.add(Flatten())
  model.add(Dense(2))
  model.add(Activation('softmax'))

except Exception as e:
  print("Error :",str(e))

# %% [markdown]
# **Compile the model**

# %%
model.save_weights("modelweights.h5")

# %%
model.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %% [markdown]
# **Train the model**

# %%
model.fit(X,y,epochs=20,validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-86bbbccdf4cf> in <module>()
# ----> 1 model.fit(X,y,epochs=20,validation_split=0.1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     707         steps=steps_per_epoch,
#     708         validation_split=validation_split,
# --> 709         shuffle=shuffle)
#     710
#     711     # Prepare validation data.
#
# ...

# %% [markdown]
# **Save the model**

# %%
model.save('my_model_16_layers.h5')

# %% [markdown]
# **Load the model**

# %%
model = tf.keras.models.load_model("my_model_16_layers.h5")

# %% [markdown]
# **Test prediction of the model**

# %%
CATEGORIES = ['Car','Landscape']
directory = '/content/Workspace/test/share2.jpg'
def prepare(filepath):
  IMG_SIZE = 400
  img_array= cv2.imread(filepath)
  new_array= cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
  return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,3)

img= plt.imread(directory)
plt.imshow(img)
plt.show()

prediction= model.predict([prepare(directory)])
print("It's a :",CATEGORIES[int(prediction[0][0])])
# Out:
# It's a : Car

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # **Programming part (Crash case)**

# %% [markdown]
# **Access workspace**

# %%
cd Workspace
# Out:
# [Errno 2] No such file or directory: 'Workspace'
# /content/Workspace

# %% [markdown]
# **Import packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pickle
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D

# %%
model = keras.models.load_model("")

# %% [markdown]
# **Load pickle data**

# %%
X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

# %% [markdown]
# **Normalize data**

# %%
X = X/255.0

# %% [markdown]
# **Create the model**

# %%
model = Sequential()
try:
  model.add(Conv2D(32,(3,3),input_shape = X.shape[1:]))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3)))
  model.add(Activation("relu"))
  model.add(Conv2D(32,(5,5)))
  model.add(Activation("relu"))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Flatten())
  model.add(Dense(64))
  model.add(Dropout(0.3))
  
  model.add(Dense(5))
  model.add(Activation('softmax'))

except Exception as e:
  print("Error :",str(e))

# %% [markdown]
# **Compile the model**

# %%
model.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %% [markdown]
# **Train the model**

# %%
model.fit(X,y,epochs=10,validation_split=0.1)
# Out:
# Train on 4246 samples, validate on 472 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 4246/4246 [==============================] - 52s 12ms/sample - loss: 0.6009 - acc: 0.6839 - val_loss: 0.4925 - val_acc: 0.8157
# Epoch 2/10
# 4246/4246 [==============================] - 43s 10ms/sample - loss: 0.4013 - acc: 0.8436 - val_loss: 0.4454 - val_acc: 0.8623
# Epoch 3/10
# 4246/4246 [==============================] - 44s 10ms/sample - loss: 0.3041 - acc: 0.8832 - val_loss: 0.2957 - val_acc: 0.8983
# Epoch 4/10
# 4246/4246 [==============================] - 44s 10ms/sample - loss: 0.2001 - acc: 0.9310 - val_loss: 0.2247 - val_acc: 0.9089
# Epoch 5/10
# ...

# %% [markdown]
# **Save the model**

# %%
model.save('my_model_16_layers.h5')

# %% [markdown]
# **Load the model**

# %%
model = tf.keras.models.load_model("my_model_16_layers.h5")

# %% [markdown]
# **Test prediction of the model**

# %%
CATEGORIES = ['Car','Landscape']
directory = '/content/Workspace/pic1.jpg'
def prepare(filepath):
  IMG_SIZE = 400
  img_array= cv2.imread(filepath)
  new_array= cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
  return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)

img= plt.imread(directory)
plt.imshow(img)
plt.show()

prediction= model.predict([prepare(directory)])
print("It's a :",CATEGORIES[int(prediction[0][0])])
# Out:
# It's a : Car

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# # **Code test**

# %%
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mat
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam
from keras.models import Model
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from sklearn.metrics import confusion_matrix
from scipy import ndimage,misc
import itertools
import imageio
import os
from google.colab.patches import cv2_imshow

# %%
mobilenet_model = keras.applications.mobilenet.MobileNet()

# %%
mobilenet_model.save("mobilenet_model.h5")

# %%
model = keras.applications.mobilenet.MobileNet()
# Out:
# W0629 20:31:44.697597 140245536872320 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0629 20:31:47.061352 140245536872320 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ...
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
model3 = Sequential()

for layer in mobilenet_model.layers:
  model3.add(layer)
  
model3.layers.pop()

for layer in model3.layers:
  layer.trainable = False
model3.add(Dense(2,activation='softmax'))

# %%
with open('modelMobileNet.txt','w') as fh:
    # Pass the file handle in as a lambda function to make it callable
    model3.summary(print_fn=lambda x: fh.write(x + '\n'))

# %%
def load_model():
  return tf.keras.models.load_model(os.path.join(os.getcwd(),os.path.join("model",os.listdir("model")[0])))

# %%
def data_augmentation(image_path,img,nombre_image_aug,gen,i):
  """Cette fonction fait le data augmentation, c'est à dire a partir d'une image 
  on gènere d'autres images pour agrandir la base de données"""

  generator = ImageDataGenerator(rotation_range=10, width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15, 
                              zoom_range=0.2, channel_shift_range=12., horizontal_flip=True)
  image = np.expand_dims(plt.imread(image_path),0)
  aug_iter = generator.flow(image)
  liste_write=["\n"+'{'+"\n==> Image : {} , Chemin : {}\n".format(img,image_path),"Génération {} des images augmentées ...\n".format(gen)
              ,"Génération terminé !\n","Sauvegarde des images en cours ...","\nLes images générées : ["]
    
  liste_write2=[]
  
  with open("images_car/log2.txt",'a') as f:
    for elt in liste_write:
      f.write(elt)
  
  print("Génération {} des images augmentées ...".format(gen))
  aug_img = [next(aug_iter)[0].astype(np.uint8) for i in range(nombre_image_aug)]
  print("Génération terminée !")
  print("Sauvegarde des images en cours ...\n")
  sauvegarde = True
  
  for file in aug_img:
    if os.path.exists('images_car/image_car_aug_{}.jpg'.format(i)) == False:
      mat.image.imsave('images_car/image_car_aug_{}.jpg'.format(i), file)

      with open("images_car/log2.txt","a") as f:
        f.write(" 'image_car_aug_{}.jpg' ".format(i))
      i+=1
    else:
      print("- image_car_aug_{}.jpg existe dèja".format(i))
      i+=1
      sauvegarde = False
      continue
    
  if sauvegarde:
    print("\nnxxx> Sauvegarde terminée !")
  else:
    with open("images_car/log2.txt","a") as f:
        f.write(" Pas d'images générées car elles existent dèja ")
    print("\nxxx> Pas de sauvegarde car les fichiers existent dèja !!\n")
  
  with open("images_car/log2.txt","a") as f:
      f.write("]"+"\n}")
  
  return i
  """ 
  liste=[]
  
  for file in os.listdir(path):
    if file != ".ipynb_checkpoints":
      imageout=plt.imread(os.path.join(path,file))
      liste.append(imageout)
    else:
      continue
   """

# %%
gen=1
val=0

#os.makedirs('images_car')

with open("images_car/log2.txt","w") as f:
  f.write("========================= Log of data augmentation 2 ==========================\n")

for img in os.listdir(os.path.join(os.getcwd(),"train/Car")):
  val=data_augmentation(os.path.join(os.path.join(os.getcwd(),"train/Car"),img),img,100,gen,val)
  gen+=1
# Out:
# Génération 1 des images augmentées ...
# Génération terminée !
# Sauvegarde des images en cours ...
#
# - image_car_aug_0.jpg existe dèja
# - image_car_aug_1.jpg existe dèja
# - image_car_aug_2.jpg existe dèja
# - image_car_aug_3.jpg existe dèja
# - image_car_aug_4.jpg existe dèja
# - image_car_aug_5.jpg existe dèja
# - image_car_aug_6.jpg existe dèja
# - image_car_aug_7.jpg existe dèja
# - image_car_aug_8.jpg existe dèja
# - image_car_aug_9.jpg existe dèja
# - image_car_aug_10.jpg existe dèja
# - image_car_aug_11.jpg existe dèja
# - image_car_aug_12.jpg existe dèja
# - image_car_aug_13.jpg existe dèja
# - image_car_aug_14.jpg existe dèja
# - image_car_aug_15.jpg existe dèja
# - image_car_aug_16.jpg existe dèja
# - image_car_aug_17.jpg existe dèja
# - image_car_aug_18.jpg existe dèja
# - image_car_aug_19.jpg existe dèja
# - image_car_aug_20.jpg existe dèja
# - image_car_aug_21.jpg existe dèja
# - image_car_aug_22.jpg existe dèja
# - image_car_aug_23.jpg existe dèja
# ...

# %%
with open("images_car/log2.txt","r") as f:
  for i in f.readlines():
    print(i)

# %%
rm -r images_car

# %%
i=0
def ouadni(i):
  for ind in range(10):
    i+=1
  print("i1 =",i)
  return i
  
print("i2 =",ouadni(i))
# Out:
# i1 = 10
# i2 = 10

# %%
os.listdir(os.path.join(os.getcwd(),"train/Car"))
# Out:
# ['00857.jpg',
#  '01602.jpg',
#  '01615.jpg',
#  '01688.jpg',
#  '01720.jpg',
#  '02272.jpg',
#  '02060.jpg',
#  '00578.jpg',
#  '00430.jpg',
#  '00725.jpg',
#  '00736.jpg',
#  '00112.jpg',
#  '02096.jpg',
#  '01265.jpg',
#  '02316.jpg',
#  '02271.jpg',
#  '00657.jpg',
#  '01321.jpg',
#  '01954.jpg',
#  '00795.jpg',
#  '02097.jpg',
#  '00178.jpg',
#  '02203.jpg',
#  '01671.jpg',
#  '00468.jpg',
#  '00172.jpg',
#  '00625.jpg',
#  '00616.jpg',
#  '02137.jpg',
#  '00751.jpg',
#  '00368.jpg',
#  '01038.jpg',
#  '00188.jpg',
#  '01329.jpg',
#  '01120.jpg',
#  '02267.jpg',
#  '01487.jpg',
#  '02131.jpg',
#  '00651.jpg',
#  '01747.jpg',
#  '00556.jpg',
#  '00873.jpg',
#  '00375.jpg',
#  '01107.jpg',
#  '01660.jpg',
#  '00449.jpg',
#  '02243.jpg',
#  '01183.jpg',
#  '02235.jpg',
#  '00550.jpg',
#  '00687.jpg',
#  '00442.jpg',
#  '00895.jpg',
#  '01593.jpg',
#  '01802.jpg',
#  '02014.jpg',
#  '00315.jpg',
#  '02083.jpg',
#  '01539.jpg',
#  '00859.jpg',
#  '02168.jpg',
#  '01932.jpg',
# ...

# %%
x = model.layers[-6].output
predictions = Dense(2,activation="softmax")(x)
model2 = Model(inputs=model.input,outputs=predictions)

for layer in model2.layers[:-5]:
  layer.trainable = False

model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# ...

# %%
model2.save("MobileNet.h5")

# %%
generator = ImageDataGenerator(rotation_range=10, width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15, 
                              zoom_range=0.2, channel_shift_range=12., horizontal_flip=True)

# %%
image_path = "/content/Workspace/test/pic1.jpg"

# %%
image = np.expand_dims(plt.imread(image_path),0)
aug_iter = generator.flow(image)

# %%
aug_img = [next(aug_iter)[0].astype(np.uint8) for i in range(100)]

# %%
#os.makedirs('images')
i=0
for file in aug_img:
  #imageio.imwrite(, file)
  mat.image.imsave('images/image_{}.jpg'.format(i), file)
  i+=1
path = "images/"
liste=[]
for file in os.listdir(path):
  if file != ".ipynb_checkpoints":
    imageout=plt.imread(os.path.join(path,file))
    liste.append(imageout)
  else:
    continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-8748890e44d1> in <module>()
#       2 for file in aug_img:
#       3   #imageio.imwrite(, file)
# ----> 4   mat.image.imsave('images/image_{}.jpg'.format(i), file)
#       5   i+=1
#       6 path = "images/"
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi)
#    1423         FigureCanvas(fig)
#    1424         fig.figimage(arr, cmap=cmap, vmin=vmin, vmax=vmax, origin=origin,
# -> 1425                      resize=True)
#    1426         fig.savefig(fname, dpi=dpi, format=format, transparent=True)
#    1427
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in figimage(self, X, xo, yo, alpha, norm, cmap, vmin, vmax, origin, resize, **kwargs)
#     860         im.stale_callback = _stale_figure_callback
#     861
# ...

# %%
#plots(aug_img, figsize=(16,7), rows=2)
plots(liste[5:20], figsize=(10,7), rows=2)

# %%
#test_path = 'Workspace/test'

#train_batches = ImageDataGenerator().flow_from_directory(train_path, traget_size=(224,224),classes=['Car','Landscape'],batch_size=10)

vgg16_model = keras.applications.vgg16.VGG16()
#vgg16_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Sequential()
for layer in vgg16_model.layers:
  model.add(layer)
#model.summary()

# %%
model.layers.pop()
for layer in model.layers:
  layer.trainable = False
model.add(Dense(2,activation='softmax'))

# %%
cd Workspace
# !unzip training.zip

# %%
# !mkdir train
# !mv Car Landscape train

# %%
model.save("vgg16_model.h5")
#model.summary()

# %%
# !cp "vgg16_model.h5" /content/gdrive/'My Drive'/Colab/vgg16_model.h5

# %%
pwd
# Out:
# '/content/Workspace'

# %%
# !mkdir train
# !mv Car Landscape train

# %%
train_path = '/content/Workspace/train'
#test_path = '/content/Workspace/test'
test_datagen = ImageDataGenerator(rescale=1./255)
train_batches =test_datagen.flow_from_directory(train_path, target_size=(224,224),classes=['Car','Landscape'],batch_size=10)
#test_batches  =ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224),classes=['Car','Landscape'],batch_size=5)
# Out:
# Found 4718 images belonging to 2 classes.

# %%
image = np.copy(plt.imread("test/Landscape/share2.jpg"))
liste = np.ndarray.tolist(image[0])
liste2 = []
for i in liste:
  liste2.append(sum(i))
print(sum(liste2),", ",len(image[0]))
print("before normalization :\n\n",image)
image2 = keras.utils.normalize(x=image, axis=-1, order=2)
print("after normalization :\n\n",image2)
# Out:
# 235962 ,  720
# before normalization :
#
#  [[[183 155 121]
#   [164 135 101]
#   [152 123  90]
#   ...
#   [107  81  58]
#   [101  75  52]
#   [ 96  71  47]]
#
#  [[167 138 105]
#   [152 123  90]
#   [159 130  97]
#   ...
#   [121  95  72]
#   [105  79  56]
#   [ 93  67  44]]
#
#  [[183 155 121]
#   [150 121  87]
#   [153 124  91]
#   ...
#   [106  80  59]
#   [102  76  55]
#   [100  74  53]]
#
#  ...
#
#  [[ 51  35  32]
#   [ 41  26  22]
#   [ 34  19  15]
#   ...
#   [ 31  18  13]
#   [ 33  20  15]
#   [ 34  21  16]]
#
#  [[ 52  37  33]
#   [ 39  24  20]
#   [ 47  32  28]
#   ...
#   [ 33  20  15]
#   [ 39  26  21]
#   [ 43  30  26]]
#
#  [[ 65  49  45]
#   [ 44  28  25]
#   [ 53  38  34]
#   ...
#   [ 34  21  16]
#   [ 43  30  26]
#   [ 50  37  33]]]
# after normalization :
#
#  [[[0.68126782 0.57703012 0.45045577]
#   [0.69726026 0.57396424 0.42941028]
#   [0.7061523  0.57142587 0.41811649]
#   ...
#   [0.73188168 0.55404127 0.39672091]
#   [0.74196542 0.55096442 0.382002  ]
# ...

# %%
#!mkdir Car Landscape
#!mv test/pic1.jpg test/pic2.jpeg test/share2.jpg Landscape
#!mv test/vehicle.jpg test/vehicle2.jpg Car
#!mv test/vehicle2.jpg Car
#!mv Car Landscape test
#!rm -r test/vehicle2.jpg
# Out:
# rm: cannot remove 'test/vehicle2.jpg': No such file or directory

# %%
def plots (ims,figsize=(12,6),rows=1,interp=False, titles=None):
  if type([ims[0]])is np.ndarray:
    ims = np.array(ims).astype(np.unit8)
    if (ims.shape[-1] != 3):
      ims = ims.transpose((0,2,3,1))
  f = plt.figure(figsize=figsize)
  cols = len(ims)//rows if len(ims)%2 == 0 else len(ims)//rows +1
  for i in range(len(ims)):
    sp = f.add_subplot(rows,cols,i+1)
    sp.axis('Off')
    if titles is not None:
      sp.set_title(titles[i],fontsize=10)
    plt.imshow(ims[i],interpolation=None if interp else 'none')

# %%
imgs, labels = next(train_batches)

# %%
plt.imshow(imgs[1])
plt.show()

# %%
plots(imgs,titles=labels)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1191: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
model.compile(Adam(lr=.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(train_batches,steps_per_epoch=235,epochs=10)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 235/235 [==============================] - 38s 162ms/step - loss: 0.6915 - acc: 0.7004
# Epoch 2/10
# 235/235 [==============================] - 34s 144ms/step - loss: 0.6893 - acc: 0.7587
# Epoch 3/10
# 235/235 [==============================] - 35s 148ms/step - loss: 0.6870 - acc: 0.8003
# Epoch 4/10
# 235/235 [==============================] - 34s 144ms/step - loss: 0.6846 - acc: 0.8230
# Epoch 5/10
# 235/235 [==============================] - 34s 144ms/step - loss: 0.6824 - acc: 0.8135
# Epoch 6/10
# 235/235 [==============================] - 34s 144ms/step - loss: 0.6802 - acc: 0.8068
# Epoch 7/10
# 235/235 [==============================] - 34s 144ms/step - loss: 0.6778 - acc: 0.8201
# Epoch 8/10
# ...

# %%
predictions = model.predict_generator(test_batches,steps=1,verbose=0)

# %%
print(predictions)
# Out:
# [[0.480301   0.519699  ]
#  [0.48922336 0.51077664]
#  [0.48918492 0.5108151 ]
#  [0.49503624 0.50496376]
#  [0.4870512  0.5129488 ]]

# %%
# !mkdir test
# !mv *.jpg pic2.jpeg test

# %%
from zipfile import ZipFile
zip_file = ZipFile.ZipFile('temp.zip', 'w')
zip_file.write("/content/Workspace", compress_type=zipfile.ZIP_DEFLATED)
zip_file.close()

# %%
import os
import zipfile

def zipdir(path, ziph):
    # ziph is zipfile handle
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file))

if __name__ == '__main__':
    zipf = zipfile.ZipFile('Workspace.zip', 'w', zipfile.ZIP_DEFLATED)
    zipdir('Workspace/', zipf)
    zipf.close()

# %%
cd ..
# Out:
# /content

# %%
# !cp /content/Workspace.zip /content/MobileNet.h5 /content/gdrive/'My Drive'/Colab

# %%
# !wget https://github.com/RomRoc/objdet_train_tensorflow_colab/archive/master.zip
# Out:
# --2019-05-30 12:54:41--  https://github.com/RomRoc/objdet_train_tensorflow_colab/archive/master.zip
# Resolving github.com (github.com)... 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/RomRoc/objdet_train_tensorflow_colab/zip/master [following]
# --2019-05-30 12:54:47--  https://codeload.github.com/RomRoc/objdet_train_tensorflow_colab/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5000664 (4.8M) [application/zip]
# Saving to: ‘master.zip’
#
# master.zip          100%[===================>]   4.77M  20.8MB/s    in 0.2s
#
# 2019-05-30 12:54:47 (20.8 MB/s) - ‘master.zip’ saved [5000664/5000664]

# %% [markdown]
# # Comparaison des models:
# - VGG16
# - MobileNet
# - Yolo

# %% [markdown]
# **Les imports**

# %%
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mat
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.optimizers import Adam
from keras.models import Model
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from sklearn.metrics import confusion_matrix
from scipy import ndimage,misc
import itertools
import imageio
import os
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Copier les models et le Workspace et les images augmentées**

# %%
# !cp /content/gdrive/'My Drive'/Colab/MobileNet.h5 /content/gdrive/'My Drive'/Colab/vgg16_model.h5 /content/gdrive/'My Drive'/Colab/Workspace.zip /content/gdrive/'My Drive'/Colab/augmentated_images.zip /content

# %% [markdown]
# **Préparer le workspace**

# %%
# !unzip Workspace.zip

# %%
# !unzip augmentated_images.zip

# %%
# !mv images_car/*.jpg Workspace/train/Car

# %%
rm -r images_car/ Workspace/images augmentated_images.zip

# %% [markdown]
# **1) Model VGG16**

# %%
vgg16_model = keras.applications.vgg16.VGG16()

model2 = Sequential()

for layer in vgg16_model.layers:
  model2.add(layer)
  
model2.layers.pop()

for layer in model2.layers:
  layer.trainable = False
model2.add(Dense(2,activation='softmax'))

# %%
with open('modelvgg16.txt','w') as fh:
    # Pass the file handle in as a lambda function to make it callable
    model2.summary(print_fn=lambda x: fh.write(x + '\n'))

# %%
with open("modelvgg16.txt","r") as f:
  for i in f.readlines():
    print(i)
# Out:
# _________________________________________________________________
#
# Layer (type)                 Output Shape              Param #
#
# ...
#
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
#
# _________________________________________________________________
#
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
#
# _________________________________________________________________
#
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
#
# _________________________________________________________________
#
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
#
# _________________________________________________________________
#
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
#
# _________________________________________________________________
#
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
#
# _________________________________________________________________
#
# ...

# %% [markdown]
# **Préparation data train et test**

# %%
train_path = '/content/Workspace/train'
test_path = '/content/Workspace/test'
test_datagen = ImageDataGenerator(rescale=1./255)
train_batches =test_datagen.flow_from_directory(train_path, target_size=(224,224),classes=['Car','Landscape'],batch_size=10)
test_batches  =ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224),classes=['Car','Landscape'],batch_size=5)
# Out:
# Found 4718 images belonging to 2 classes.
# Found 5 images belonging to 2 classes.

# %%
# !mv pic1.jpg pic2.jpeg share2.jpg Landscape
# !mv vehicle.jpg vehicle2.jpg Car

# %%
mkdir Car Landscape

# %% [markdown]
#  **Fonction d'affichage**

# %%
def plots (ims,figsize=(12,6),rows=1,interp=False, titles=None):
  if type([ims[0]])is np.ndarray:
    ims = np.array(ims).astype(np.unit8)
    if (ims.shape[-1] != 3):
      ims = ims.transpose((0,2,3,1))
  f = plt.figure(figsize=figsize)
  cols = len(ims)//rows if len(ims)%2 == 0 else len(ims)//rows +1
  for i in range(len(ims)):
    sp = f.add_subplot(rows,cols,i+1)
    sp.axis('Off')
    if titles is not None:
      sp.set_title(titles[i],fontsize=10)
    plt.imshow(ims[i],interpolation=None if interp else 'none')

# %% [markdown]
# **Affichage des batches**

# %%
imgs, labels = next(train_batches)

# %%
plots(imgs,titles=labels)

# %% [markdown]
# **Compiling model**

# %%
model.compile(Adam(lr=.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# **Train model**

# %%
model.fit_generator(train_batches,steps_per_epoch=235,epochs=20)
# Out:
# Epoch 1/20
# 235/235 [==============================] - 17s 70ms/step - loss: 0.6701 - acc: 0.8369
# Epoch 2/20
# 235/235 [==============================] - 17s 73ms/step - loss: 0.6676 - acc: 0.8540
# Epoch 3/20
# 235/235 [==============================] - 17s 71ms/step - loss: 0.6653 - acc: 0.8407
# Epoch 4/20
# 235/235 [==============================] - 16s 70ms/step - loss: 0.6634 - acc: 0.8451
# Epoch 5/20
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6616 - acc: 0.8404
# Epoch 6/20
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6586 - acc: 0.8409
# Epoch 7/20
# 235/235 [==============================] - 16s 70ms/step - loss: 0.6570 - acc: 0.8429
# Epoch 8/20
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6553 - acc: 0.8366
# Epoch 9/20
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6521 - acc: 0.8382
# Epoch 10/20
# ...

# %% [markdown]
# **Prediction**

# %%
predictions = model.predict_generator(test_batches,steps=1,verbose=0)
print(predictions)
# Out:
# [[0.48598552 0.5140145 ]
#  [0.2678552  0.73214483]
#  [0.4645266  0.53547347]
#  [0.24068336 0.7593166 ]
#  [0.3521474  0.6478526 ]]
